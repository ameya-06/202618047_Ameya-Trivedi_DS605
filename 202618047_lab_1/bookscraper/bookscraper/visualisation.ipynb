# %%
#Plot 1: Price Distribution
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud


df = pd.read_csv("C:/Users/Hirav/Downloads/ML Assignment/202618047_Ameya-Trivedi_DS605/202618047_lab_1/bookscraper/books.csv")


plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=10, edgecolor="black")
plt.title("Price Distribution")
plt.xlabel("Price (£)")
plt.ylabel("Number of Books")
plt.savefig("price_distribution.png")
plt.show()

# %% [markdown]
# we can conclude that the price distribtion is almost equally distributed in the data

# %%
#  Rating Distribution
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

df = pd.read_csv("C:/Users/Hirav/Downloads/ML Assignment/202618047_Ameya-Trivedi_DS605/202618047_lab_1/bookscraper/books.csv")

plt.figure(figsize=(6,5))
df["rating"].value_counts().sort_index().plot(kind="bar")
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.savefig("rating_distribution.png")
plt.show()

# %% [markdown]
# we can see that we have more rating one n three books

# %%
# Average Price by Category
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("C:/Users/Hirav/Downloads/ML Assignment/202618047_Ameya-Trivedi_DS605/202618047_lab_1/bookscraper/books.csv")


# Convert price to numeric (remove £ symbol)
df["price"] = df["price"].str.replace("£", "").astype(float)

# Group by category and calculate average price
avg_price = df.groupby("category")["price"].mean().sort_values()

# Plot
plt.figure(figsize=(10, 6))
avg_price.plot(kind="bar", color="skyblue")
plt.title("Average Price by Category")
plt.xlabel("Category")
plt.ylabel("Average Price (£)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.savefig("average_price_by_category.png")
plt.show()

# %% [markdown]
# we can see that most books are ok historical fiction and least of spirutality

# %%
# Price vs Rating
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))
plt.scatter(df["rating"], df["price"], color="orange", alpha=0.7)
plt.title("Price vs Rating")
plt.xlabel("Rating")
plt.ylabel("Price (£)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig("price_vs_rating.png")
plt.show()

# %% [markdown]
# we can wee that for each rating the price distribtuin is normal , we have books from low price to preminum in each rating

# %%
# ==========================================================
# Graph 5 : Word Cloud
# ==========================================================

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# Load the cleaned dataset (adjust path if needed)
df = pd.read_csv("C:/Users/Hirav/Downloads/ML Assignment/202618047_Ameya-Trivedi_DS605/202618047_lab_1/bookscraper/books.csv")

# Combine all book descriptions into one text block
text = " ".join(df["product_description"].fillna(""))

# Generate the word cloud
wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color="white"
).generate(text)

# Plot the word cloud
plt.figure(figsize=(15,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in Book Descriptions")
plt.savefig("wordcloud.png")
plt.show()

# %% [markdown]
# most used words are one , life , love , live , time which are all related to life and daily basis
